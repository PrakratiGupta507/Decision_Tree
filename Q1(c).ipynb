# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE
from scipy.io import loadmat
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = loadmat("/content/gdrive/My Drive/ML_Assignment/Dataset/dataset_1.mat")
X = data['samples']
X=X.reshape(50000,28*28 )
X=pd.DataFrame(data=X)
X_embedded = TSNE(n_components =2).fit_transform(X)

# %%
X_embedded.shape
# Out:
# (50000, 2)

# %%
df = pd.DataFrame(X_embedded)
label=data['labels'][0]
lable=label.tolist()
df['label']=lable
df.head()
# Out:
#            0          1  label
# 0  -0.136595  29.163031      5
# 1 -33.637878   9.202753      0
# 2  -2.790472 -51.111160      4
# 3 -19.862448 -40.264030      1
# 4  18.616663 -22.121201      9

# %%
df.columns = ['x', 'y', 'class'] 
df.head()
# Out:
#            x          y  class
# 0  -0.136595  29.163031      5
# 1 -33.637878   9.202753      0
# 2  -2.790472 -51.111160      4
# 3 -19.862448 -40.264030      1
# 4  18.616663 -22.121201      9

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df, x="x", y="y", hue="class",palette="deep")
